# %% [markdown]
# <a href="https://colab.research.google.com/github/gunavathibaskaran170/DeepLearning/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, LSTM ,Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist

# %%
mnist=keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train,x_test=x_train/255,x_test/255

# %%
input_shape =(28,28)
inputs= Input(shape=input_shape)
rnnh=LSTM(128)(inputs)
outputs= Dense(10,activation='softmax')(rnnh)
model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # why did flatten means because image is multidimension so that we have to use the flatten
# RNN read only one word er second
# # why RNN doesn't do the flatten because during the Flatten it read the text from the left to right so word order got changed  these all the word become single

# %%
rnn_model=model.fit(x_train,y_train,validation_split=0.1,epochs=3)
# Out:
# Epoch 1/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 68s 39ms/step - accuracy: 0.8858 - loss: 0.3525 - val_accuracy: 0.9620 - val_loss: 0.1255
# Epoch 2/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 66s 39ms/step - accuracy: 0.9659 - loss: 0.1125 - val_accuracy: 0.9790 - val_loss: 0.0771
# Epoch 3/3
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 64s 38ms/step - accuracy: 0.9771 - loss: 0.0756 - val_accuracy: 0.9843 - val_loss: 0.0561
