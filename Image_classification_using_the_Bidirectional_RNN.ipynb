# %% [markdown]
# <a href="https://colab.research.google.com/github/gunavathibaskaran170/DeepLearning/blob/main/Image_classification_using_the_Bidirectional_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input,LSTM,Dense,Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
x_train=x_train.reshape((60000, 28, 28)).astype('float32')/255
x_test=x_test.reshape((10000, 28, 28)).astype('float32')/255

# %%
from tensorflow.keras.utils import to_categorical
x_train=to_categorical(x_train)
x_test=to_categorical(x_test)

# %%
inputs=Input(shape=(28,28))
rnn_layer=Bidirectional(LSTM(128))(inputs)
outputs=Dense(10,activation='softmax')(rnn_layer)
model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
x_train_fixed = x_train[:, :, :, 0]
rnn_model = model.fit(x_train_fixed, y_train, validation_split=0.1, epochs=8)
# Out:
# Epoch 1/8
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 25ms/step - accuracy: 0.1129 - loss: 2.3014 - val_accuracy: 0.1050 - val_loss: 2.3017
# Epoch 2/8
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 80s 24ms/step - accuracy: 0.1132 - loss: 2.3014 - val_accuracy: 0.1050 - val_loss: 2.3019
# Epoch 3/8
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.1129 - loss: 2.3014 - val_accuracy: 0.1050 - val_loss: 2.3019
# Epoch 4/8
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.1132 - loss: 2.3013 - val_accuracy: 0.1050 - val_loss: 2.3018
# Epoch 5/8
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - accuracy: 0.1132 - loss: 2.3013 - val_accuracy: 0.1050 - val_loss: 2.3018
# Epoch 6/8
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.1132 - loss: 2.3013 - val_accuracy: 0.1050 - val_loss: 2.3019
# Epoch 7/8
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 44s 26ms/step - accuracy: 0.1129 - loss: 2.3013 - val_accuracy: 0.1050 - val_loss: 2.3019
# Epoch 8/8
# ...
